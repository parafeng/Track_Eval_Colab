# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/lab/Bee/Track_Eval/
# Out:
# /content/drive/MyDrive/lab/Bee/Track_Eval

# %%
import os
#một vài thay đổi ở các phiên bản
file_path = "/content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/metrics/identity.py"

with open(file_path, 'r') as f:
    content = f.read()
modified_content = content.replace('np.int', 'np.int64')

with open(file_path, 'w') as f:
    f.write(modified_content)

print("File updated successfully!")
# Out:
# File updated successfully!

# %%
import glob

base_path = "/content/drive/MyDrive/lab/Bee/Track_Eval"
python_files = glob.glob(f"{base_path}/**/*.py", recursive=True)

for file_path in python_files:
    try:
        with open(file_path, 'r') as f:
            content = f.read()

        if 'np.int' in content:
            print(f"Found np.int in {file_path}")

            #modified_content = content.replace('np.int', 'np.int64') something wrong here !
            modified_content = content.replace('np.int6464', 'np.int64')

            with open(file_path, 'w') as f:
                f.write(modified_content)

            print(f"  - Fixed {file_path}")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

print("All files processed!")
# Out:
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/baselines/stp.py
#   - Fixed /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/baselines/stp.py
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/bdd100k.py
#   - Fixed /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/bdd100k.py
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/davis.py
#   - Fixed /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/davis.py
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/head_tracking_challenge.py
#   - Fixed /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/head_tracking_challenge.py
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/kitti_2d_box.py
#   - Fixed /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/kitti_2d_box.py
# Found np.int in /content/drive/MyDrive/lab/Bee/Track_Eval/trackeval/datasets/kitti_mots.py
# ...

# %%
# !python scripts/run_mot_challenge.py
# Out:
# ____________________________________eval_config______________________________________
# {'USE_PARALLEL': False, 'NUM_PARALLEL_CORES': 8, 'BREAK_ON_ERROR': True, 'RETURN_ON_ERROR': False, 'LOG_ON_ERROR': '/content/drive/MyDrive/lab/Bee/Track_Eval/error_log.txt', 'PRINT_RESULTS': True, 'PRINT_ONLY_COMBINED': False, 'PRINT_CONFIG': True, 'TIME_PROGRESS': True, 'DISPLAY_LESS_PROGRESS': False, 'OUTPUT_SUMMARY': True, 'OUTPUT_EMPTY_CLASSES': True, 'OUTPUT_DETAILED': True, 'PLOT_CURVES': True}
# ____________________________________dataset_config___________________________________
# ...
